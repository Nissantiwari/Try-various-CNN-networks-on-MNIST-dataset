# %%
# Credits: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py


from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 146s 2ms/step - loss: 0.2543 - accuracy: 0.9231 - val_loss: 0.0660 - val_accuracy: 0.9787
# Epoch 2/12
# 60000/60000 [==============================] - 146s 2ms/step - loss: 0.0864 - accuracy: 0.9740 - val_loss: 0.0385 - val_accuracy: 0.9870
# Epoch 3/12
# 60000/60000 [==============================] - 146s 2ms/step - loss: 0.0643 - accuracy: 0.9812 - val_loss: 0.0330 - val_accuracy: 0.9893
# Epoch 4/12
# 60000/60000 [==============================] - 151s 3ms/step - loss: 0.0536 - accuracy: 0.9840 - val_loss: 0.0287 - val_accuracy: 0.9901
# Epoch 5/12
# 60000/60000 [==============================] - 146s 2ms/step - loss: 0.0477 - accuracy: 0.9856 - val_loss: 0.0297 - val_accuracy: 0.9899
# Epoch 6/12
# 60000/60000 [==============================] - 146s 2ms/step - loss: 0.0417 - accuracy: 0.9876 - val_loss: 0.0291 - val_accuracy: 0.9898
# Epoch 7/12
# 60000/60000 [==============================] - 145s 2ms/step - loss: 0.0379 - accuracy: 0.9890 - val_loss: 0.0266 - val_accuracy: 0.9918
# Epoch 8/12
# 60000/60000 [==============================] - 150s 2ms/step - loss: 0.0348 - accuracy: 0.9892 - val_loss: 0.0282 - val_accuracy: 0.9905
# Epoch 9/12
# 60000/60000 [==============================] - 144s 2ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0294 - val_accuracy: 0.9910
# Epoch 10/12
# 60000/60000 [==============================] - 145s 2ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.0253 - val_accuracy: 0.9922
# Epoch 11/12
# 60000/60000 [==============================] - 145s 2ms/step - loss: 0.0271 - accuracy: 0.9916 - val_loss: 0.0285 - val_accuracy: 0.9916
# Epoch 12/12
# 60000/60000 [==============================] - 145s 2ms/step - loss: 0.0267 - accuracy: 0.9917 - val_loss: 0.0293 - val_accuracy: 0.9911
# Test loss: 0.029274762150908646
# Test accuracy: 0.991100013256073

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Assignment 13: Using vaious CNN architectures on MNIST data set.

# %%
# Credits: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py


from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# if you keras is not using tensorflow as backend set "KERAS_BACKEND=tensorflow" use this command
from keras.utils import np_utils 
from keras.datasets import mnist 
import seaborn as sns
from keras.initializers import RandomNormal

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import time
# https://gist.github.com/greydanus/f6eee59eaf1d90fcb3b534a25362cea4
# https://stackoverflow.com/a/14434334
# this function is used to update the plots for each epoch and error
def plt_dynamic(x, vy, ty, ax, colors=['b']):
    ax.plot(x, vy, 'b', label="Validation Loss")
    ax.plot(x, ty, 'r', label="Train Loss")
    plt.legend()
    plt.grid()
    fig.canvas.draw()

# %% [markdown]
# ## 1. 2 Convulational Layers with 3*3 kernels and Maxpool and Dropout for each layers:

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 49s 822us/step - loss: 0.3538 - accuracy: 0.8886 - val_loss: 0.0770 - val_accuracy: 0.9753
# Epoch 2/12
# 60000/60000 [==============================] - 49s 818us/step - loss: 0.1223 - accuracy: 0.9631 - val_loss: 0.0500 - val_accuracy: 0.9832
# Epoch 3/12
# 60000/60000 [==============================] - 49s 818us/step - loss: 0.0897 - accuracy: 0.9727 - val_loss: 0.0418 - val_accuracy: 0.9867
# Epoch 4/12
# 60000/60000 [==============================] - 49s 822us/step - loss: 0.0750 - accuracy: 0.9778 - val_loss: 0.0335 - val_accuracy: 0.9880
# Epoch 5/12
# 60000/60000 [==============================] - 49s 820us/step - loss: 0.0685 - accuracy: 0.9787 - val_loss: 0.0290 - val_accuracy: 0.9896
# Epoch 6/12
# 60000/60000 [==============================] - 49s 820us/step - loss: 0.0611 - accuracy: 0.9813 - val_loss: 0.0282 - val_accuracy: 0.9900
# Epoch 7/12
# 60000/60000 [==============================] - 49s 818us/step - loss: 0.0548 - accuracy: 0.9832 - val_loss: 0.0251 - val_accuracy: 0.9921
# Epoch 8/12
# 60000/60000 [==============================] - 49s 819us/step - loss: 0.0510 - accuracy: 0.9850 - val_loss: 0.0265 - val_accuracy: 0.9903
# Epoch 9/12
# 60000/60000 [==============================] - 49s 818us/step - loss: 0.0485 - accuracy: 0.9856 - val_loss: 0.0237 - val_accuracy: 0.9916
# Epoch 10/12
# 60000/60000 [==============================] - 49s 818us/step - loss: 0.0464 - accuracy: 0.9860 - val_loss: 0.0243 - val_accuracy: 0.9925
# Epoch 11/12
# 60000/60000 [==============================] - 49s 814us/step - loss: 0.0456 - accuracy: 0.9864 - val_loss: 0.0234 - val_accuracy: 0.9915
# Epoch 12/12
# 60000/60000 [==============================] - 49s 814us/step - loss: 0.0425 - accuracy: 0.9871 - val_loss: 0.0227 - val_accuracy: 0.9921
# Test loss: 0.022677877272697516
# Test accuracy: 0.9921000003814697

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.022677877272697516
# Test accuracy: 0.9921000003814697

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')


plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# ## 2. 2 Convulational Layers with 5*5 kernels and Maxpool and Dropout for each layers:

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 59s 978us/step - loss: 0.3174 - accuracy: 0.8992 - val_loss: 0.0639 - val_accuracy: 0.9802
# Epoch 2/12
# 60000/60000 [==============================] - 58s 973us/step - loss: 0.1004 - accuracy: 0.9693 - val_loss: 0.0371 - val_accuracy: 0.9883
# Epoch 3/12
# 60000/60000 [==============================] - 58s 969us/step - loss: 0.0737 - accuracy: 0.9777 - val_loss: 0.0286 - val_accuracy: 0.9914
# Epoch 4/12
# 60000/60000 [==============================] - 58s 969us/step - loss: 0.0607 - accuracy: 0.9821 - val_loss: 0.0261 - val_accuracy: 0.9912
# Epoch 5/12
# 60000/60000 [==============================] - 58s 963us/step - loss: 0.0533 - accuracy: 0.9842 - val_loss: 0.0264 - val_accuracy: 0.9911
# Epoch 6/12
# 60000/60000 [==============================] - 58s 964us/step - loss: 0.0484 - accuracy: 0.9859 - val_loss: 0.0223 - val_accuracy: 0.9932
# Epoch 7/12
# 60000/60000 [==============================] - 58s 960us/step - loss: 0.0417 - accuracy: 0.9869 - val_loss: 0.0194 - val_accuracy: 0.9933
# Epoch 8/12
# 60000/60000 [==============================] - 58s 959us/step - loss: 0.0391 - accuracy: 0.9883 - val_loss: 0.0193 - val_accuracy: 0.9937
# Epoch 9/12
# 60000/60000 [==============================] - 58s 966us/step - loss: 0.0371 - accuracy: 0.9892 - val_loss: 0.0199 - val_accuracy: 0.9934
# Epoch 10/12
# 60000/60000 [==============================] - 58s 962us/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.0201 - val_accuracy: 0.9932
# Epoch 11/12
# 60000/60000 [==============================] - 58s 960us/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.0171 - val_accuracy: 0.9945
# Epoch 12/12
# 60000/60000 [==============================] - 58s 961us/step - loss: 0.0305 - accuracy: 0.9907 - val_loss: 0.0174 - val_accuracy: 0.9936
# Test loss: 0.01738732848415675
# Test accuracy: 0.9936000108718872

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.01738732848415675
# Test accuracy: 0.9936000108718872

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')


plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# ## 3. 2 Convulational Layers with 7*7 kernels and Maxpool and Dropout for each layers:

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(7, 7),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(45, (7, 7), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 49s 811us/step - loss: 0.3967 - accuracy: 0.8760 - val_loss: 0.0798 - val_accuracy: 0.9755
# Epoch 2/12
# 60000/60000 [==============================] - 53s 879us/step - loss: 0.1214 - accuracy: 0.9646 - val_loss: 0.0467 - val_accuracy: 0.9843
# Epoch 3/12
# 60000/60000 [==============================] - 48s 804us/step - loss: 0.0914 - accuracy: 0.9736 - val_loss: 0.0360 - val_accuracy: 0.9884
# Epoch 4/12
# 60000/60000 [==============================] - 48s 802us/step - loss: 0.0729 - accuracy: 0.9787 - val_loss: 0.0312 - val_accuracy: 0.9904
# Epoch 5/12
# 60000/60000 [==============================] - 48s 803us/step - loss: 0.0622 - accuracy: 0.9813 - val_loss: 0.0285 - val_accuracy: 0.9903
# Epoch 6/12
# 60000/60000 [==============================] - 48s 803us/step - loss: 0.0571 - accuracy: 0.9840 - val_loss: 0.0303 - val_accuracy: 0.9899
# Epoch 7/12
# 60000/60000 [==============================] - 48s 803us/step - loss: 0.0529 - accuracy: 0.9855 - val_loss: 0.0265 - val_accuracy: 0.9922
# Epoch 8/12
# 60000/60000 [==============================] - 48s 802us/step - loss: 0.0487 - accuracy: 0.9863 - val_loss: 0.0260 - val_accuracy: 0.9917
# Epoch 9/12
# 60000/60000 [==============================] - 48s 804us/step - loss: 0.0455 - accuracy: 0.9867 - val_loss: 0.0281 - val_accuracy: 0.9911
# Epoch 10/12
# 60000/60000 [==============================] - 48s 798us/step - loss: 0.0429 - accuracy: 0.9873 - val_loss: 0.0236 - val_accuracy: 0.9927
# Epoch 11/12
# 60000/60000 [==============================] - 48s 797us/step - loss: 0.0421 - accuracy: 0.9878 - val_loss: 0.0223 - val_accuracy: 0.9932
# Epoch 12/12
# 60000/60000 [==============================] - 48s 796us/step - loss: 0.0387 - accuracy: 0.9880 - val_loss: 0.0246 - val_accuracy: 0.9923
# Test loss: 0.024618234796303658
# Test accuracy: 0.9922999739646912

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.024618234796303658
# Test accuracy: 0.9922999739646912

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')


plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# ## 4. 3 Convulational Layers with 7*7 kernels and Maxpool and Dropout for each layers:

# %%
model = Sequential()

model.add(Conv2D(60, kernel_size=(7, 7),activation='relu',input_shape=input_shape, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(45, (7, 7), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(32, (7, 7), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 415s 7ms/step - loss: 0.3617 - accuracy: 0.8829 - val_loss: 0.0507 - val_accuracy: 0.9847
# Epoch 2/12
# 60000/60000 [==============================] - 407s 7ms/step - loss: 0.0949 - accuracy: 0.9734 - val_loss: 0.0362 - val_accuracy: 0.9885
# Epoch 3/12
# 60000/60000 [==============================] - 408s 7ms/step - loss: 0.0655 - accuracy: 0.9810 - val_loss: 0.0252 - val_accuracy: 0.9923
# Epoch 4/12
# 60000/60000 [==============================] - 411s 7ms/step - loss: 0.0524 - accuracy: 0.9850 - val_loss: 0.0242 - val_accuracy: 0.9921
# Epoch 5/12
# 60000/60000 [==============================] - 408s 7ms/step - loss: 0.0461 - accuracy: 0.9875 - val_loss: 0.0214 - val_accuracy: 0.9927
# Epoch 6/12
# 60000/60000 [==============================] - 408s 7ms/step - loss: 0.0398 - accuracy: 0.9886 - val_loss: 0.0195 - val_accuracy: 0.9937
# Epoch 7/12
# 60000/60000 [==============================] - 408s 7ms/step - loss: 0.0365 - accuracy: 0.9899 - val_loss: 0.0211 - val_accuracy: 0.9931
# Epoch 8/12
# 60000/60000 [==============================] - 415s 7ms/step - loss: 0.0309 - accuracy: 0.9912 - val_loss: 0.0227 - val_accuracy: 0.9929
# Epoch 9/12
# 60000/60000 [==============================] - 416s 7ms/step - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.0245 - val_accuracy: 0.9933
# Epoch 10/12
# 60000/60000 [==============================] - 410s 7ms/step - loss: 0.0268 - accuracy: 0.9922 - val_loss: 0.0178 - val_accuracy: 0.9947
# Epoch 11/12
# 60000/60000 [==============================] - 410s 7ms/step - loss: 0.0248 - accuracy: 0.9930 - val_loss: 0.0189 - val_accuracy: 0.9947
# Epoch 12/12
# 60000/60000 [==============================] - 410s 7ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.0194 - val_accuracy: 0.9938
# Test loss: 0.019394571762404764
# Test accuracy: 0.9937999844551086

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.019394571762404764
# Test accuracy: 0.9937999844551086

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')


plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# Took lot of computation time and still not musch improvement in accuracy

# %% [markdown]
# ## 5. 3 Convolutional layer with 5*5 Kernel with dropout and MaxPool

# %%
model = Sequential()

model.add(Conv2D(30, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(60, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(120, (5, 5), activation='relu', padding= 'same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.3245 - accuracy: 0.8964 - val_loss: 0.0453 - val_accuracy: 0.9853
# Epoch 2/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0814 - accuracy: 0.9766 - val_loss: 0.0340 - val_accuracy: 0.9890
# Epoch 3/12
# 60000/60000 [==============================] - 101s 2ms/step - loss: 0.0602 - accuracy: 0.9829 - val_loss: 0.0280 - val_accuracy: 0.9911
# Epoch 4/12
# 60000/60000 [==============================] - 101s 2ms/step - loss: 0.0486 - accuracy: 0.9852 - val_loss: 0.0244 - val_accuracy: 0.9921
# Epoch 5/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0425 - accuracy: 0.9880 - val_loss: 0.0234 - val_accuracy: 0.9933
# Epoch 6/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0377 - accuracy: 0.9890 - val_loss: 0.0199 - val_accuracy: 0.9938
# Epoch 7/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0348 - accuracy: 0.9897 - val_loss: 0.0178 - val_accuracy: 0.9940
# Epoch 8/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0301 - accuracy: 0.9911 - val_loss: 0.0188 - val_accuracy: 0.9946
# Epoch 9/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0272 - accuracy: 0.9923 - val_loss: 0.0178 - val_accuracy: 0.9943
# Epoch 10/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0262 - accuracy: 0.9928 - val_loss: 0.0195 - val_accuracy: 0.9939
# Epoch 11/12
# 60000/60000 [==============================] - 102s 2ms/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 0.0185 - val_accuracy: 0.9951
# Epoch 12/12
# 60000/60000 [==============================] - 101s 2ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.0183 - val_accuracy: 0.9939
# Test loss: 0.018277256486304214
# Test accuracy: 0.9939000010490417

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.018277256486304214
# Test accuracy: 0.9939000010490417

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
h3_w = w_after[4].flatten().reshape(-1,1)
out_w = w_after[6].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 4, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 4, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 4, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h3_w, color='r')
plt.xlabel('Hidden Layer 3 ')

plt.subplot(1, 4, 4)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# This is the best model till now because of high accuracy with less computation time as compared to model with 7 kernel size.

# %% [markdown]
# ## 6. 4 Convolutional layer with 3*3 Kernel with 2 MaxPools and 2 dropouts

# %%
model = Sequential()

model.add(Conv2D(30, kernel_size=(5, 5),activation='relu',input_shape=input_shape))

model.add(Conv2D(60, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.5))

model.add(Conv2D(120, (5, 5), activation='relu'))

model.add(Conv2D(90, (5, 5), activation='relu', padding= 'same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 406s 7ms/step - loss: 0.3373 - accuracy: 0.8948 - val_loss: 0.0455 - val_accuracy: 0.9862
# Epoch 2/12
# 60000/60000 [==============================] - 402s 7ms/step - loss: 0.0763 - accuracy: 0.9787 - val_loss: 0.0303 - val_accuracy: 0.9913
# Epoch 3/12
# 60000/60000 [==============================] - 406s 7ms/step - loss: 0.0567 - accuracy: 0.9841 - val_loss: 0.0202 - val_accuracy: 0.9937
# Epoch 4/12
# 60000/60000 [==============================] - 400s 7ms/step - loss: 0.0438 - accuracy: 0.9880 - val_loss: 0.0200 - val_accuracy: 0.9945
# Epoch 5/12
# 60000/60000 [==============================] - 399s 7ms/step - loss: 0.0376 - accuracy: 0.9895 - val_loss: 0.0191 - val_accuracy: 0.9944
# Epoch 6/12
# 60000/60000 [==============================] - 400s 7ms/step - loss: 0.0323 - accuracy: 0.9908 - val_loss: 0.0196 - val_accuracy: 0.9944
# Epoch 7/12
# 60000/60000 [==============================] - 400s 7ms/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 0.0165 - val_accuracy: 0.9962
# Epoch 8/12
# 60000/60000 [==============================] - 399s 7ms/step - loss: 0.0269 - accuracy: 0.9927 - val_loss: 0.0166 - val_accuracy: 0.9951
# Epoch 9/12
# 60000/60000 [==============================] - 399s 7ms/step - loss: 0.0241 - accuracy: 0.9934 - val_loss: 0.0194 - val_accuracy: 0.9943
# Epoch 10/12
# 60000/60000 [==============================] - 399s 7ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.0155 - val_accuracy: 0.9953
# Epoch 11/12
# 60000/60000 [==============================] - 405s 7ms/step - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.0210 - val_accuracy: 0.9951
# Epoch 12/12
# 60000/60000 [==============================] - 404s 7ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.0143 - val_accuracy: 0.9959
# Test loss: 0.01430961664400077
# Test accuracy: 0.9958999752998352

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.01430961664400077
# Test accuracy: 0.9958999752998352

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
h3_w = w_after[4].flatten().reshape(-1,1)
h4_w = w_after[6].flatten().reshape(-1,1)
out_w = w_after[8].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 5, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 5, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 5, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h3_w, color='b')
plt.xlabel('Hidden Layer 3 ')

plt.subplot(1, 5, 4)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h4_w, color='r')
plt.xlabel('Hidden Layer 4 ')

plt.subplot(1, 5, 5)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# ##7. 2 Conolutional layers with 3*3 Kernels and only Maxpool, no dropout.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 44s 735us/step - loss: 0.2142 - accuracy: 0.9344 - val_loss: 0.0538 - val_accuracy: 0.9835
# Epoch 2/12
# 60000/60000 [==============================] - 44s 731us/step - loss: 0.0537 - accuracy: 0.9836 - val_loss: 0.0407 - val_accuracy: 0.9869
# Epoch 3/12
# 60000/60000 [==============================] - 44s 727us/step - loss: 0.0363 - accuracy: 0.9891 - val_loss: 0.0376 - val_accuracy: 0.9870
# Epoch 4/12
# 60000/60000 [==============================] - 44s 727us/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.0275 - val_accuracy: 0.9912
# Epoch 5/12
# 60000/60000 [==============================] - 44s 730us/step - loss: 0.0219 - accuracy: 0.9937 - val_loss: 0.0261 - val_accuracy: 0.9911
# Epoch 6/12
# 60000/60000 [==============================] - 44s 730us/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0238 - val_accuracy: 0.9918
# Epoch 7/12
# 60000/60000 [==============================] - 44s 734us/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0285 - val_accuracy: 0.9908
# Epoch 8/12
# 60000/60000 [==============================] - 44s 733us/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0260 - val_accuracy: 0.9915
# Epoch 9/12
# 60000/60000 [==============================] - 44s 729us/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.0249 - val_accuracy: 0.9925
# Epoch 10/12
# 60000/60000 [==============================] - 44s 730us/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0271 - val_accuracy: 0.9926
# Epoch 11/12
# 60000/60000 [==============================] - 44s 731us/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0234 - val_accuracy: 0.9929
# Epoch 12/12
# 60000/60000 [==============================] - 44s 730us/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0298 - val_accuracy: 0.9928
# Test loss: 0.02976533622213068
# Test accuracy: 0.9927999973297119

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.02976533622213068
# Test accuracy: 0.9927999973297119

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
out_w = w_after[4].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 3, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 3, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 3, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# ## 8. 3 Convolutional layers with 3*3 Kernel.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))

model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(Conv2D(120, (3, 3), activation='relu'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history= model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 482s 8ms/step - loss: 0.1771 - accuracy: 0.9460 - val_loss: 0.0466 - val_accuracy: 0.9845
# Epoch 2/12
# 60000/60000 [==============================] - 486s 8ms/step - loss: 0.0444 - accuracy: 0.9857 - val_loss: 0.0342 - val_accuracy: 0.9881
# Epoch 3/12
# 60000/60000 [==============================] - 482s 8ms/step - loss: 0.0259 - accuracy: 0.9918 - val_loss: 0.0356 - val_accuracy: 0.9882
# Epoch 4/12
# 60000/60000 [==============================] - 482s 8ms/step - loss: 0.0163 - accuracy: 0.9953 - val_loss: 0.0330 - val_accuracy: 0.9904
# Epoch 5/12
# 60000/60000 [==============================] - 486s 8ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0355 - val_accuracy: 0.9897
# Epoch 6/12
# 60000/60000 [==============================] - 489s 8ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0390 - val_accuracy: 0.9895
# Epoch 7/12
# 60000/60000 [==============================] - 481s 8ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0397 - val_accuracy: 0.9897
# Epoch 8/12
# 60000/60000 [==============================] - 485s 8ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0409 - val_accuracy: 0.9905
# Epoch 9/12
# 60000/60000 [==============================] - 488s 8ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0467 - val_accuracy: 0.9905
# Epoch 10/12
# 60000/60000 [==============================] - 488s 8ms/step - loss: 8.4751e-04 - accuracy: 0.9997 - val_loss: 0.0524 - val_accuracy: 0.9910
# Epoch 11/12
# 60000/60000 [==============================] - 486s 8ms/step - loss: 6.7318e-04 - accuracy: 0.9998 - val_loss: 0.0516 - val_accuracy: 0.9912
# Epoch 12/12
# 60000/60000 [==============================] - 490s 8ms/step - loss: 1.9673e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9909
# Test loss: 0.057878360452395444
# Test accuracy: 0.9908999800682068

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print('Test score:', score[0]) 
print('Test accuracy:', score[1])

fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

# print(history.history.keys())
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# history = model_drop.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch, verbose=1, validation_data=(X_test, Y_test))

# we will get val_loss and val_acc only when you pass the paramter validation_data
# val_loss : validation loss
# val_acc : validation accuracy

# loss : training loss
# acc : train accuracy
# for each key in histrory.histrory we will have a list of length equal to number of epochs


vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# Test score: 0.057878360452395444
# Test accuracy: 0.9908999800682068

# %%
w_after = model.get_weights()

h1_w = w_after[0].flatten().reshape(-1,1)
h2_w = w_after[2].flatten().reshape(-1,1)
h3_w = w_after[4].flatten().reshape(-1,1)
out_w = w_after[6].flatten().reshape(-1,1)


fig = plt.figure()
plt.title("Weight matrices after model trained")
plt.subplot(1, 4, 1)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h1_w,color='b')
plt.xlabel('Hidden Layer 1')

plt.subplot(1, 4, 2)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='r')
plt.xlabel('Hidden Layer 2 ')

plt.subplot(1, 4, 3)
plt.title("Trained model Weights")
ax = sns.violinplot(y=h2_w, color='b')
plt.xlabel('Hidden Layer 3 ')

plt.subplot(1, 4, 4)
plt.title("Trained model Weights")
ax = sns.violinplot(y=out_w,color='y')
plt.xlabel('Output Layer ')
plt.show()

# %% [markdown]
# # Observation:

# %%
from prettytable import PrettyTable
x = PrettyTable()
x.field_names = ["Sr.No","Model", "Kernels","Max_pool","Dropout", "Test Accuracy"]

x.add_row(["1","2 Conv Layers)", "3*3" ,"yes","yes", " 0.9921"])
x.add_row(["2","2 Conv Layers)", "5*5" ,"yes","yes", "0.9936"])
x.add_row(["3","2 Conv Layers)", "7*7" ,"yes","yes", "0.9922"])
x.add_row(["4","3 Conv Layers)", "7*7" ,"yes","yes", "0.9337"])
x.add_row(["5","3 Conv Layers)", "5*5" ,"yes","yes", "0.9339"])
x.add_row(["6","4 Conv Layers)", "3*3" ,"yes","yes", "0.9958"])
x.add_row(["7","3 Conv Layers)", "3*3" ,"no","yes", "0.9927"])
x.add_row(["8","3 Conv Layers)", "3*3" ,"no","no", "0.9908"])
print (x)
# Out:
# +-------+----------------+---------+----------+---------+---------------+
# | Sr.No |     Model      | Kernels | Max_pool | Dropout | Test Accuracy |
# +-------+----------------+---------+----------+---------+---------------+
# |   1   | 2 Conv Layers) |   3*3   |   yes    |   yes   |     0.9921    |
# |   2   | 2 Conv Layers) |   5*5   |   yes    |   yes   |     0.9936    |
# |   3   | 2 Conv Layers) |   7*7   |   yes    |   yes   |     0.9922    |
# |   4   | 3 Conv Layers) |   7*7   |   yes    |   yes   |     0.9337    |
# |   5   | 3 Conv Layers) |   5*5   |   yes    |   yes   |     0.9339    |
# |   6   | 4 Conv Layers) |   3*3   |   yes    |   yes   |     0.9958    |
# |   7   | 3 Conv Layers) |   3*3   |    no    |   yes   |     0.9927    |
# |   8   | 3 Conv Layers) |   3*3   |    no    |    no   |     0.9908    |
# +-------+----------------+---------+----------+---------+---------------+

# %% [markdown]
# # Conclusion:

# %% [markdown]
# 1. Although most of the models performed almost same, Last model (Sr.8) which has no 'Dropouts' and no 'Maxpool' performed worst and had least accuracy of all.
# 2. Highest accuracy is by the model which had 4 layers of 3*3 Kernels, with maxpool and dropouts.
# 3. In addition to that one can also observe form above table that increasing the number of layers, along with 'maxpool' and 'dropouts' did improve the accuracy.
